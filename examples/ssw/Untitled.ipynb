# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,2*np.pi,20)
y = np.sin(x)

# %%
plt.figure(facecolor=(1,1,1))
plt.plot(x,y)
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.tight_layout()
plt.savefig("/scratch/jf4241/ecmwf_data/results/tpt_quantities/2022-08-23/sinfig")
